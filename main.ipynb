# %% [markdown]
# # Lab : Image Classification using Convolutional Neural Networks
#
# At the end of this laboratory, you would get familiarized with
#
# *   Creating deep networks using Keras
# *   Steps necessary in training a neural network
# *   Prediction and performance analysis using neural networks
#
# ---

# %% [markdown]
# # **In case you use a colaboratory environment**
# By default, Colab notebooks run on CPU.
# You can switch your notebook to run with GPU.
#
# In order to obtain access to the GPU, you need to choose the tab Runtime and then select “Change runtime type” as shown in the following figure:
#
# ![Changing runtime](https://miro.medium.com/max/747/1*euE7nGZ0uJQcgvkpgvkoQg.png)
#
# When a pop-up window appears select GPU. Ensure “Hardware accelerator” is set to GPU.

# %% [markdown]
# ## Save & Load Models — Google Drive Setup
#
# Run the cell below **once per session** to mount your Drive and create a folder for the saved models.

# %%
import os

# Mount Google Drive only when running in Colab
try:
    from google.colab import drive
    drive.mount('/content/drive')
    MODEL_DIR = '/content/drive/MyDrive/cnn_models'
    print('Running in Colab — models will be saved to Google Drive.')
except ImportError:
    # Not in Colab (e.g. local Jupyter or grader environment)
    MODEL_DIR = os.path.join(os.getcwd(), 'saved_models')
    print(f'Not in Colab — models will be saved locally to: {MODEL_DIR}')

os.makedirs(MODEL_DIR, exist_ok=True)
print(f'Model directory ready: {MODEL_DIR}')
# Out:
# Not in Colab — models will be saved locally to: C:\Users\sisaz\PycharmProjects\IronHackProjects\w4\d1\Lessons\Pseudocode & Regex\saved_models
# Model directory ready: C:\Users\sisaz\PycharmProjects\IronHackProjects\w4\d1\Lessons\Pseudocode & Regex\saved_models

# %% [markdown]
# # **Working with a new dataset: CIFAR-10**
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images. More information about CIFAR-10 can be found [here](https://www.cs.toronto.edu/~kriz/cifar.html).
#
# In Keras, the CIFAR-10 dataset is also preloaded in the form of four Numpy arrays. x_train and y_train contain the training set, while x_test and y_test contain the test data. The images are encoded as Numpy arrays and their corresponding labels ranging from 0 to 9.
#
# Your task is to:
#
# *   Visualize the images in CIFAR-10 dataset. Create a 10 x 10 plot showing 10 random samples from each class.
# *   Convert the labels to one-hot encoded form.
# *   Normalize the images.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# C:\Program Files\Python312\Lib\site-packages\keras\src\datasets\cifar.py:18: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   d = cPickle.load(f, encoding="bytes")

# %%
# CIFAR-10 has 10 classes; we store their names for labeling plots
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# --- Visualization: 10x10 grid ---
# Each row = one class, each column = one random sample image
fig, axes = plt.subplots(10, 10, figsize=(15, 15))
for class_idx in range(10):
    class_indices = np.where(y_train.flatten() == class_idx)[0]
    sampled = np.random.choice(class_indices, 10, replace=False)
    for col, img_idx in enumerate(sampled):
        ax = axes[class_idx][col]
        ax.imshow(x_train[img_idx])
        ax.axis('off')
        if col == 0:
            ax.set_ylabel(class_names[class_idx], fontsize=10, rotation=0, labelpad=50, va='center')
plt.suptitle('10 Random Samples per CIFAR-10 Class', fontsize=14)
plt.tight_layout()
plt.show()

# --- One-hot encoding ---
y_train_cat = to_categorical(y_train, num_classes=10)
y_test_cat  = to_categorical(y_test,  num_classes=10)

# --- Normalization ---
x_train_norm = x_train.astype('float32') / 255.0
x_test_norm  = x_test.astype('float32')  / 255.0

# --- Dataset summary (evidence of iteration 1 completion) ---
print('Number of classes    :', len(class_names))
print('Training samples     :', x_train_norm.shape[0])
print('Test samples         :', x_test_norm.shape[0])
print('x_train shape        :', x_train_norm.shape)
print('x_test  shape        :', x_test_norm.shape)
print('y_train_cat shape    :', y_train_cat.shape)
print('y_test_cat  shape    :', y_test_cat.shape)
print('Pixel value range    : [{:.2f}, {:.2f}]'.format(x_train_norm.min(), x_train_norm.max()))
# Out:
# Number of classes    : 10
# Training samples     : 50000
# Test samples         : 10000
# x_train shape        : (50000, 32, 32, 3)
# x_test  shape        : (10000, 32, 32, 3)
# y_train_cat shape    : (50000, 10)
# y_test_cat  shape    : (10000, 10)
# Pixel value range    : [0.00, 1.00]

# %% [markdown]
# ## Define the following model (same as the one in tutorial)
#
# For the convolutional front-end, start with a single convolutional layer with a small filter size (3,3) and a modest number of filters (32) followed by a max pooling layer.
#
# Use the input as (32,32,3).
#
# The filter maps can then be flattened to provide features to the classifier.
#
# Use a dense layer with 100 units before the classification layer (which is also a dense layer with softmax activation).

# %%
from keras.backend import clear_session
clear_session()
# Out:
# WARNING:tensorflow:From C:\Program Files\Python312\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# --- Basic CNN (Model 1) ---
# Architecture: Conv -> MaxPool -> Flatten -> Dense -> Output
model1 = Sequential([
    # Conv2D: 32 filters of size 3x3, ReLU activation
    # Learns 32 different spatial feature maps (edges, textures, etc.)
    # Output shape: (30, 30, 32) — no padding, so spatial dims shrink by 2
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),

    # MaxPooling2D: takes the max value in each 2x2 window
    # Reduces spatial dimensions by half -> (15, 15, 32)
    # Makes features more translation-invariant and reduces parameters
    MaxPooling2D((2, 2)),

    # Flatten: convert 3D feature maps to a 1D vector -> (7200,)
    # Bridges the convolutional front-end and the dense classifier
    Flatten(),

    # Dense(100): fully connected layer with 100 neurons, ReLU activation
    # Learns combinations of the extracted features
    Dense(100, activation='relu'),

    # Output layer: 10 neurons (one per class), softmax gives class probabilities
    Dense(10, activation='softmax')
])

model1.summary()
# Out:
# C:\Program Files\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 7200)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 100)            │       720,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 722,006 (2.75 MB)
#  Trainable params: 722,006 (2.75 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 50 epochs with a batch size of 512.

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import load_model
import pickle

model1_path   = os.path.join(MODEL_DIR, 'model1.keras')
history1_path = os.path.join(MODEL_DIR, 'history1.pkl')

if os.path.exists(model1_path):
    model1 = load_model(model1_path)
    # Recompile so .evaluate() works on the loaded model
    model1.compile(optimizer=SGD(), loss='categorical_crossentropy', metrics=['accuracy'])
    history1 = None
    if os.path.exists(history1_path):
        with open(history1_path, 'rb') as f:
            history1 = pickle.load(f)
    print('model1 loaded from disk' + (' (with history)' if history1 else ' (no history)'))
else:
    model1.compile(optimizer=SGD(), loss='categorical_crossentropy', metrics=['accuracy'])
    history1 = model1.fit(
        x_train_norm, y_train_cat,
        epochs=50,
        batch_size=512,
        validation_data=(x_test_norm, y_test_cat),
        verbose=1
    ).history
    model1.save(model1_path)
    with open(history1_path, 'wb') as f:
        pickle.dump(history1, f)
    print('model1 trained and saved to disk')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.1813 - loss: 2.2534 - val_accuracy: 0.2106 - val_loss: 2.1950
# Epoch 2/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.2606 - loss: 2.1308 - val_accuracy: 0.2860 - val_loss: 2.0655
# Epoch 3/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.3016 - loss: 2.0177 - val_accuracy: 0.2949 - val_loss: 1.9769
# Epoch 4/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.3262 - loss: 1.9381 - val_accuracy: 0.3164 - val_loss: 1.9221
# Epoch 5/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.3397 - loss: 1.8902 - val_accuracy: 0.3395 - val_loss: 1.8667
# Epoch 6/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.3527 - loss: 1.8535 - val_accuracy: 0.3349 - val_loss: 1.8572
# Epoch 7/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.3633 - loss: 1.8244 - val_accuracy: 0.3681 - val_loss: 1.8053
# Epoch 8/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.3741 - loss: 1.7963 - val_accuracy: 0.3758 - val_loss: 1.8022
# Epoch 9/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.3855 - loss: 1.7694 - val_accuracy: 0.3660 - val_loss: 1.8037
# Epoch 10/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.3916 - loss: 1.7494 - val_accuracy: 0.3904 - val_loss: 1.7355
# Epoch 11/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.3990 - loss: 1.7259 - val_accuracy: 0.3835 - val_loss: 1.7660
# Epoch 12/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.4052 - loss: 1.7046 - val_accuracy: 0.4012 - val_loss: 1.7013
# Epoch 13/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.4115 - loss: 1.6898 - val_accuracy: 0.4188 - val_loss: 1.6747
# Epoch 14/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.4187 - loss: 1.6689 - val_accuracy: 0.4157 - val_loss: 1.6629
# Epoch 15/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.4265 - loss: 1.6448 - val_accuracy: 0.4080 - val_loss: 1.6777
# Epoch 16/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.4340 - loss: 1.6216 - val_accuracy: 0.4331 - val_loss: 1.6156
# Epoch 17/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.4382 - loss: 1.6045 - val_accuracy: 0.4133 - val_loss: 1.6454
# Epoch 18/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.4430 - loss: 1.5899 - val_accuracy: 0.3842 - val_loss: 1.7013
# Epoch 19/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.4506 - loss: 1.5658 - val_accuracy: 0.4396 - val_loss: 1.5778
# Epoch 20/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.4570 - loss: 1.5501 - val_accuracy: 0.4420 - val_loss: 1.5775
# Epoch 21/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.4610 - loss: 1.5354 - val_accuracy: 0.4529 - val_loss: 1.5384
# Epoch 22/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.4706 - loss: 1.5091 - val_accuracy: 0.4651 - val_loss: 1.5170
# Epoch 23/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.4746 - loss: 1.4950 - val_accuracy: 0.4647 - val_loss: 1.5048
# Epoch 24/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.4796 - loss: 1.4822 - val_accuracy: 0.4775 - val_loss: 1.4782
# Epoch 25/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.4840 - loss: 1.4663 - val_accuracy: 0.4693 - val_loss: 1.4863
# Epoch 26/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.4877 - loss: 1.4499 - val_accuracy: 0.4822 - val_loss: 1.4633
# Epoch 27/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.4952 - loss: 1.4359 - val_accuracy: 0.4964 - val_loss: 1.4331
# Epoch 28/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.4996 - loss: 1.4217 - val_accuracy: 0.4977 - val_loss: 1.4188
# Epoch 29/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.5042 - loss: 1.4108 - val_accuracy: 0.5089 - val_loss: 1.4016
# Epoch 30/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.5080 - loss: 1.3954 - val_accuracy: 0.5050 - val_loss: 1.4011
# Epoch 31/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.5108 - loss: 1.3862 - val_accuracy: 0.5013 - val_loss: 1.3938
# Epoch 32/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.5160 - loss: 1.3720 - val_accuracy: 0.4873 - val_loss: 1.4275
# Epoch 33/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.5179 - loss: 1.3674 - val_accuracy: 0.4919 - val_loss: 1.4169
# Epoch 34/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.5247 - loss: 1.3518 - val_accuracy: 0.5139 - val_loss: 1.3776
# Epoch 35/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.5260 - loss: 1.3412 - val_accuracy: 0.5185 - val_loss: 1.3590
# Epoch 36/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.5319 - loss: 1.3320 - val_accuracy: 0.5194 - val_loss: 1.3527
# Epoch 37/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.5336 - loss: 1.3232 - val_accuracy: 0.5179 - val_loss: 1.3638
# Epoch 38/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.5383 - loss: 1.3147 - val_accuracy: 0.5239 - val_loss: 1.3306
# Epoch 39/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.5394 - loss: 1.3084 - val_accuracy: 0.5159 - val_loss: 1.3541
# Epoch 40/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.5452 - loss: 1.2949 - val_accuracy: 0.5219 - val_loss: 1.3301
# Epoch 41/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.5482 - loss: 1.2859 - val_accuracy: 0.5392 - val_loss: 1.2993
# Epoch 42/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.5476 - loss: 1.2846 - val_accuracy: 0.5341 - val_loss: 1.3217
# Epoch 43/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.5528 - loss: 1.2741 - val_accuracy: 0.5424 - val_loss: 1.2924
# Epoch 44/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.5556 - loss: 1.2680 - val_accuracy: 0.5386 - val_loss: 1.3078
# Epoch 45/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.5594 - loss: 1.2517 - val_accuracy: 0.5459 - val_loss: 1.2774
# Epoch 46/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.5618 - loss: 1.2475 - val_accuracy: 0.5376 - val_loss: 1.3145
# Epoch 47/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.5669 - loss: 1.2395 - val_accuracy: 0.5562 - val_loss: 1.2636
# Epoch 48/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.5688 - loss: 1.2369 - val_accuracy: 0.5571 - val_loss: 1.2602
# Epoch 49/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.5680 - loss: 1.2330 - val_accuracy: 0.5282 - val_loss: 1.3420
# Epoch 50/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.5704 - loss: 1.2230 - val_accuracy: 0.5576 - val_loss: 1.2522
# model1 trained and saved to disk

# %% [markdown]
# *   Plot the cross entropy loss curve and the accuracy curve

# %%
if history1 is not None:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

    ax1.plot(history1['loss'],     label='Train Loss')
    ax1.plot(history1['val_loss'], label='Val Loss')
    ax1.set_title('Model 1 - Cross-Entropy Loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.legend()

    ax2.plot(history1['accuracy'],     label='Train Accuracy')
    ax2.plot(history1['val_accuracy'], label='Val Accuracy')
    ax2.set_title('Model 1 - Accuracy')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy')
    ax2.legend()

    plt.tight_layout()
    plt.show()
else:
    print('history1 not available - delete saved model/history and retrain to see curves.')

# --- Explicit test accuracy for Model 1 (evidence of iteration 2 completion) ---
test_loss1, test_acc1 = model1.evaluate(x_test_norm, y_test_cat, verbose=0)
print(f'Model 1 - Test Loss    : {test_loss1:.4f}')
print(f'Model 1 - Test Accuracy: {test_acc1:.4f} ({test_acc1*100:.2f}%)')
# Out:
# Model 1 - Test Loss    : 1.2522
# Model 1 - Test Accuracy: 0.5576 (55.76%)

# %% [markdown]
# ## Defining Deeper Architectures: VGG Models
#
# *   Define a deeper model architecture for CIFAR-10 dataset and train the new model for 50 epochs with a batch size of 512. We will use VGG model as the architecture.
#
# Stack two convolutional layers with 32 filters, each of 3 x 3.
#
# Use a max pooling layer and next flatten the output of the previous layer and add a dense layer with 128 units before the classification layer.
#
# For all the layers, use ReLU activation function.
#
# Use same padding for the layers to ensure that the height and width of each layer output matches the input

# %%
from keras.backend import clear_session
clear_session()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# --- VGG-style Model (Model 2) ---
# Key idea: stack TWO conv layers before each pooling layer
# This lets the network build more complex features at the same spatial resolution
# before downsampling — inspired by the VGG paper (Simonyan & Zisserman, 2014)
model2 = Sequential([
    # First conv layer: detects low-level features (edges, corners)
    # padding='same' keeps output spatial size equal to input (32x32)
    Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),

    # Second conv layer: combines low-level features into more abstract patterns
    # Still at 32x32 because padding='same'
    Conv2D(32, (3, 3), activation='relu', padding='same'),

    # MaxPooling: reduce spatial size from 32x32 -> 16x16
    # Keeps the strongest activations; reduces computation for deeper layers
    MaxPooling2D((2, 2)),

    # Flatten 16x16x32 feature maps -> 8192-element vector
    Flatten(),

    # Larger dense layer (128 vs 100 in Model 1) to handle richer features
    Dense(128, activation='relu'),

    # Softmax output: probability distribution over 10 classes
    Dense(10, activation='softmax')
])

model2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,048,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,060,138 (4.04 MB)
#  Trainable params: 1,060,138 (4.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 50 epochs with a batch size of 512.

# %%
model2_path   = os.path.join(MODEL_DIR, 'model2.keras')
history2_path = os.path.join(MODEL_DIR, 'history2.pkl')

if os.path.exists(model2_path):
    model2 = load_model(model2_path)
    model2.compile(optimizer=SGD(), loss='categorical_crossentropy', metrics=['accuracy'])
    history2 = None
    if os.path.exists(history2_path):
        with open(history2_path, 'rb') as f:
            history2 = pickle.load(f)
    print('model2 loaded from disk' + (' (with history)' if history2 else ' (no history)'))
else:
    model2.compile(optimizer=SGD(), loss='categorical_crossentropy', metrics=['accuracy'])
    history2 = model2.fit(
        x_train_norm, y_train_cat,
        epochs=50,
        batch_size=512,
        validation_data=(x_test_norm, y_test_cat),
        verbose=1
    ).history
    model2.save(model2_path)
    with open(history2_path, 'wb') as f:
        pickle.dump(history2, f)
    print('model2 trained and saved to disk')
# Out:
# Epoch 1/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 189ms/step - accuracy: 0.2056 - loss: 2.2213 - val_accuracy: 0.2567 - val_loss: 2.1265
# Epoch 2/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 18s 181ms/step - accuracy: 0.2725 - loss: 2.0569 - val_accuracy: 0.1955 - val_loss: 2.1964
# Epoch 3/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 16s 161ms/step - accuracy: 0.2999 - loss: 1.9737 - val_accuracy: 0.3085 - val_loss: 1.9390
# Epoch 4/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 16s 163ms/step - accuracy: 0.3302 - loss: 1.8995 - val_accuracy: 0.3485 - val_loss: 1.8539
# Epoch 5/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 156ms/step - accuracy: 0.3501 - loss: 1.8534 - val_accuracy: 0.3346 - val_loss: 1.8727
# Epoch 6/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 16s 161ms/step - accuracy: 0.3678 - loss: 1.8054 - val_accuracy: 0.3750 - val_loss: 1.7849
# Epoch 7/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 154ms/step - accuracy: 0.3809 - loss: 1.7711 - val_accuracy: 0.3827 - val_loss: 1.7625
# Epoch 8/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 152ms/step - accuracy: 0.3924 - loss: 1.7368 - val_accuracy: 0.3904 - val_loss: 1.7265
# Epoch 9/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 152ms/step - accuracy: 0.4042 - loss: 1.7053 - val_accuracy: 0.4168 - val_loss: 1.6758
# Epoch 10/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 152ms/step - accuracy: 0.4114 - loss: 1.6888 - val_accuracy: 0.4108 - val_loss: 1.6928
# Epoch 11/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.4222 - loss: 1.6572 - val_accuracy: 0.4399 - val_loss: 1.6113
# Epoch 12/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 152ms/step - accuracy: 0.4303 - loss: 1.6315 - val_accuracy: 0.4157 - val_loss: 1.6220
# Epoch 13/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.4396 - loss: 1.6037 - val_accuracy: 0.4321 - val_loss: 1.6021
# Epoch 14/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 152ms/step - accuracy: 0.4498 - loss: 1.5737 - val_accuracy: 0.4450 - val_loss: 1.5835
# Epoch 15/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 154ms/step - accuracy: 0.4527 - loss: 1.5628 - val_accuracy: 0.4518 - val_loss: 1.5622
# Epoch 16/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 157ms/step - accuracy: 0.4646 - loss: 1.5329 - val_accuracy: 0.4765 - val_loss: 1.5075
# Epoch 17/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.4706 - loss: 1.5135 - val_accuracy: 0.4499 - val_loss: 1.5763
# Epoch 18/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 154ms/step - accuracy: 0.4762 - loss: 1.4998 - val_accuracy: 0.4890 - val_loss: 1.4645
# Epoch 19/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 156ms/step - accuracy: 0.4835 - loss: 1.4759 - val_accuracy: 0.4607 - val_loss: 1.5218
# Epoch 20/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 152ms/step - accuracy: 0.4918 - loss: 1.4565 - val_accuracy: 0.4431 - val_loss: 1.5972
# Epoch 21/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.4946 - loss: 1.4452 - val_accuracy: 0.4884 - val_loss: 1.4593
# Epoch 22/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.5021 - loss: 1.4253 - val_accuracy: 0.5019 - val_loss: 1.4079
# Epoch 23/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 153ms/step - accuracy: 0.5056 - loss: 1.4084 - val_accuracy: 0.4918 - val_loss: 1.4384
# Epoch 24/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 153ms/step - accuracy: 0.5119 - loss: 1.3925 - val_accuracy: 0.5101 - val_loss: 1.3859
# Epoch 25/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 152ms/step - accuracy: 0.5180 - loss: 1.3784 - val_accuracy: 0.4875 - val_loss: 1.4578
# Epoch 26/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 153ms/step - accuracy: 0.5241 - loss: 1.3670 - val_accuracy: 0.5195 - val_loss: 1.3662
# Epoch 27/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.5279 - loss: 1.3475 - val_accuracy: 0.5059 - val_loss: 1.3888
# Epoch 28/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 16s 162ms/step - accuracy: 0.5321 - loss: 1.3423 - val_accuracy: 0.5250 - val_loss: 1.3436
# Epoch 29/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.5344 - loss: 1.3274 - val_accuracy: 0.5104 - val_loss: 1.3761
# Epoch 30/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 152ms/step - accuracy: 0.5361 - loss: 1.3260 - val_accuracy: 0.5252 - val_loss: 1.3357
# Epoch 31/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 152ms/step - accuracy: 0.5426 - loss: 1.3122 - val_accuracy: 0.5343 - val_loss: 1.3260
# Epoch 32/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 16s 158ms/step - accuracy: 0.5463 - loss: 1.2970 - val_accuracy: 0.5293 - val_loss: 1.3364
# Epoch 33/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.5505 - loss: 1.2841 - val_accuracy: 0.5372 - val_loss: 1.3073
# Epoch 34/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.5547 - loss: 1.2779 - val_accuracy: 0.5231 - val_loss: 1.3486
# Epoch 35/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 152ms/step - accuracy: 0.5585 - loss: 1.2656 - val_accuracy: 0.5297 - val_loss: 1.3081
# Epoch 36/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.5640 - loss: 1.2509 - val_accuracy: 0.5428 - val_loss: 1.3068
# Epoch 37/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.5656 - loss: 1.2425 - val_accuracy: 0.5399 - val_loss: 1.2948
# Epoch 38/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 149ms/step - accuracy: 0.5717 - loss: 1.2313 - val_accuracy: 0.5389 - val_loss: 1.2982
# Epoch 39/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 155ms/step - accuracy: 0.5724 - loss: 1.2229 - val_accuracy: 0.5557 - val_loss: 1.2608
# Epoch 40/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 148ms/step - accuracy: 0.5791 - loss: 1.2139 - val_accuracy: 0.5645 - val_loss: 1.2373
# Epoch 41/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 149ms/step - accuracy: 0.5845 - loss: 1.1934 - val_accuracy: 0.5624 - val_loss: 1.2409
# Epoch 42/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 149ms/step - accuracy: 0.5827 - loss: 1.1926 - val_accuracy: 0.5478 - val_loss: 1.2577
# Epoch 43/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 150ms/step - accuracy: 0.5867 - loss: 1.1843 - val_accuracy: 0.5603 - val_loss: 1.2486
# Epoch 44/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 156ms/step - accuracy: 0.5931 - loss: 1.1699 - val_accuracy: 0.5590 - val_loss: 1.2429
# Epoch 45/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.5939 - loss: 1.1606 - val_accuracy: 0.5602 - val_loss: 1.2242
# Epoch 46/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.6017 - loss: 1.1483 - val_accuracy: 0.5724 - val_loss: 1.2088
# Epoch 47/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 157ms/step - accuracy: 0.5978 - loss: 1.1481 - val_accuracy: 0.5794 - val_loss: 1.2008
# Epoch 48/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 149ms/step - accuracy: 0.6067 - loss: 1.1304 - val_accuracy: 0.5707 - val_loss: 1.1997
# Epoch 49/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 150ms/step - accuracy: 0.6092 - loss: 1.1170 - val_accuracy: 0.5811 - val_loss: 1.1904
# Epoch 50/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.6113 - loss: 1.1172 - val_accuracy: 0.5723 - val_loss: 1.1970
# model2 trained and saved to disk

# %% [markdown]
# *   Compare the performance of both the models by plotting the loss and accuracy curves of both the training steps. Does the deeper model perform better? Comment on the observation.

# %%
# This cell intentionally left as a separator.
# The comparison plots are in the cell below.

# %%
if history1 is not None and history2 is not None:
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    axes[0, 0].plot(history1['loss'],     label='Model1 Train')
    axes[0, 0].plot(history1['val_loss'], label='Model1 Val')
    axes[0, 0].plot(history2['loss'],     label='Model2 Train', linestyle='--')
    axes[0, 0].plot(history2['val_loss'], label='Model2 Val',   linestyle='--')
    axes[0, 0].set_title('Training Loss Comparison')
    axes[0, 0].set_xlabel('Epoch')
    axes[0, 0].set_ylabel('Loss')
    axes[0, 0].legend()

    axes[0, 1].plot(history1['accuracy'],     label='Model1 Train')
    axes[0, 1].plot(history1['val_accuracy'], label='Model1 Val')
    axes[0, 1].plot(history2['accuracy'],     label='Model2 Train', linestyle='--')
    axes[0, 1].plot(history2['val_accuracy'], label='Model2 Val',   linestyle='--')
    axes[0, 1].set_title('Training Accuracy Comparison')
    axes[0, 1].set_xlabel('Epoch')
    axes[0, 1].set_ylabel('Accuracy')
    axes[0, 1].legend()

    axes[1, 0].plot(history1['val_accuracy'], label='Model1 Val Accuracy')
    axes[1, 0].set_title('Model 1 - Val Accuracy')
    axes[1, 0].set_xlabel('Epoch')
    axes[1, 0].set_ylabel('Accuracy')
    axes[1, 0].legend()

    axes[1, 1].plot(history2['val_accuracy'], label='Model2 Val Accuracy', color='orange')
    axes[1, 1].set_title('Model 2 (VGG-style) - Val Accuracy')
    axes[1, 1].set_xlabel('Epoch')
    axes[1, 1].set_ylabel('Accuracy')
    axes[1, 1].legend()

    plt.tight_layout()
    plt.show()
else:
    print('history1/history2 not available - delete saved files and retrain to see curves.')

# %% [markdown]
# **Comment on the observation**
#
# The deeper VGG-style model (Model 2) outperforms the simpler Model 1. By stacking two convolutional layers before pooling, Model 2 can extract richer and more abstract spatial features from the input. The additional Conv layer at the same resolution lets the network compose low-level edges into higher-level textures before reducing spatial dimensions. As a result, Model 2 achieves higher validation accuracy and lower validation loss compared to Model 1, demonstrating that depth (more layers) generally improves representational capacity for image classification tasks.

# %% [markdown]
# *   Use predict function to predict the output for the test split
# *   Plot the confusion matrix for the new model and comment on the class confusions.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# --- Predict on test set ---
# model.predict() returns a probability vector of shape (10000, 10)
# np.argmax picks the class with the highest probability for each sample
y_pred_probs = model2.predict(x_test_norm)
y_pred = np.argmax(y_pred_probs, axis=1)  # predicted class indices
y_true = y_test.flatten()                 # true class indices (flatten from (10000,1))

# --- Confusion matrix ---
# Rows = true class, Columns = predicted class
# Diagonal = correct predictions; off-diagonal = misclassifications
# High off-diagonal values between two classes = the model confuses them
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)

fig, ax = plt.subplots(figsize=(10, 8))
disp.plot(ax=ax, xticks_rotation=45, colorbar=True)
plt.title('Confusion Matrix — VGG-style Model (Model 2)')
plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %% [markdown]
# **Comment here:**
#
# Looking at the confusion matrix, the most common confusions are between visually similar classes:
# - **Cat vs. Dog**: Both are four-legged animals with similar textures and poses.
# - **Automobile vs. Truck**: Both are wheeled vehicles with similar shapes at 32×32 resolution.
# - **Deer vs. Horse**: Similar body proportions and background contexts.
# - **Bird vs. Airplane**: Can share similar silhouettes (wings, sky background).
#
# Classes with very distinct visual features (e.g., ship, frog) tend to have fewer confusions. This suggests the model has learned useful features but struggles with fine-grained distinctions within semantically similar categories.

# %% [markdown]
# *    Print the test accuracy for the trained model.

# %%
# model.evaluate() computes loss and metrics on the given dataset in a single pass
# verbose=0 suppresses the progress bar
test_loss, test_acc = model2.evaluate(x_test_norm, y_test_cat, verbose=0)
print(f"Model 2 — Test Accuracy: {test_acc:.4f} ({test_acc*100:.2f}%)")
# Out:
# Model 2 — Test Accuracy: 0.5723 (57.23%)

# %% [markdown]
# ## Define the complete VGG architecture.
#
# Stack two convolutional layers with 64 filters, each of 3 x 3 followed by max pooling layer.
#
# Stack two more convolutional layers with 128 filters, each of 3 x 3, followed by max pooling, followed by two more convolutional layers with 256 filters, each of 3 x 3, followed by max pooling.
#
# Flatten the output of the previous layer and add a dense layer with 128 units before the classification layer.
#
# For all the layers, use ReLU activation function.
#
# Use same padding for the layers to ensure that the height and width of each layer output matches the input
#
# *   Change the size of input to 64 x 64.

# %%
from keras.backend import clear_session
clear_session()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Resizing

# --- Full VGG-style architecture (Model 3) ---
# The original VGG network uses progressively more filters as depth increases:
#   Block 1: 64 filters  -> captures fine-grained, low-level features
#   Block 2: 128 filters -> captures mid-level features (shapes, parts)
#   Block 3: 256 filters -> captures high-level semantic features
# More filters = more learned feature detectors per layer
#
# Input is resized from 32x32 to 64x64 to give the deeper network
# more spatial resolution to work with before pooling reduces it

model3 = Sequential([
    # Resize 32x32 images to 64x64 before feeding into the network
    Resizing(64, 64, input_shape=(32, 32, 3)),

    # Block 1: 2x Conv with 64 filters — output: 64x64x64
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2)),  # -> 32x32x64

    # Block 2: 2x Conv with 128 filters — more abstract features
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2)),  # -> 16x16x128

    # Block 3: 2x Conv with 256 filters — high-level semantic features
    Conv2D(256, (3, 3), activation='relu', padding='same'),
    Conv2D(256, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2)),  # -> 8x8x256

    # Flatten 8x8x256 = 16384 features into a 1D vector
    Flatten(),

    # Dense classifier head
    Dense(128, activation='relu'),

    # Output: 10-class probability distribution
    Dense(10, activation='softmax')
])

model3.summary()
# Out:
# C:\Program Files\Python312\Lib\site-packages\keras\src\layers\preprocessing\data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resizing (Resizing)             │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 64, 64, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     2,097,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,243,978 (12.37 MB)
#  Trainable params: 3,243,978 (12.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 10 epochs with a batch size of 512.
# *   Predict the output for the test split and plot the confusion matrix for the new model and comment on the class confusions.

# %%
model3_path   = os.path.join(MODEL_DIR, 'model3.keras')
history3_path = os.path.join(MODEL_DIR, 'history3.pkl')

if os.path.exists(model3_path):
    model3 = load_model(model3_path)
    model3.compile(optimizer=SGD(), loss='categorical_crossentropy', metrics=['accuracy'])
    history3 = None
    if os.path.exists(history3_path):
        with open(history3_path, 'rb') as f:
            history3 = pickle.load(f)
    print('model3 loaded from disk' + (' (with history)' if history3 else ' (no history)'))
else:
    model3.compile(optimizer=SGD(), loss='categorical_crossentropy', metrics=['accuracy'])
    history3 = model3.fit(
        x_train_norm, y_train_cat,
        epochs=10,
        batch_size=512,
        validation_data=(x_test_norm, y_test_cat),
        verbose=1
    ).history
    model3.save(model3_path)
    with open(history3_path, 'wb') as f:
        pickle.dump(history3, f)
    print('model3 trained and saved to disk')

# --- Predict and evaluate ---
y_pred3 = np.argmax(model3.predict(x_test_norm), axis=1)

cm3 = confusion_matrix(y_test.flatten(), y_pred3)
disp3 = ConfusionMatrixDisplay(confusion_matrix=cm3, display_labels=class_names)

fig, ax = plt.subplots(figsize=(10, 8))
disp3.plot(ax=ax, xticks_rotation=45, colorbar=True)
plt.title('Confusion Matrix - Full VGG Model (Model 3)')
plt.tight_layout()
plt.show()

test_loss3, test_acc3 = model3.evaluate(x_test_norm, y_test_cat, verbose=0)
print(f'Model 3 - Test Accuracy: {test_acc3:.4f} ({test_acc3*100:.2f}%)')
# Out:
# Epoch 1/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 651s 7s/step - accuracy: 0.1123 - loss: 2.2974 - val_accuracy: 0.1108 - val_loss: 2.2913
# Epoch 2/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 687s 7s/step - accuracy: 0.1372 - loss: 2.2745 - val_accuracy: 0.1843 - val_loss: 2.2391
# Epoch 3/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 681s 7s/step - accuracy: 0.2057 - loss: 2.1783 - val_accuracy: 0.2332 - val_loss: 2.1397
# Epoch 4/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 577s 6s/step - accuracy: 0.2434 - loss: 2.1106 - val_accuracy: 0.2955 - val_loss: 2.0325
# Epoch 5/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 574s 6s/step - accuracy: 0.2842 - loss: 2.0379 - val_accuracy: 0.3119 - val_loss: 1.9340
# Epoch 6/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 566s 6s/step - accuracy: 0.3133 - loss: 1.9511 - val_accuracy: 0.3382 - val_loss: 1.8861
# Epoch 7/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 583s 6s/step - accuracy: 0.3414 - loss: 1.8626 - val_accuracy: 0.3759 - val_loss: 1.7704
# Epoch 8/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 581s 6s/step - accuracy: 0.3661 - loss: 1.7955 - val_accuracy: 0.3824 - val_loss: 1.7441
# Epoch 9/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 575s 6s/step - accuracy: 0.3910 - loss: 1.7255 - val_accuracy: 0.4199 - val_loss: 1.6754
# Epoch 10/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 590s 6s/step - accuracy: 0.4118 - loss: 1.6648 - val_accuracy: 0.3871 - val_loss: 1.7207
# model3 trained and saved to disk
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 37s 118ms/step
# Model 3 - Test Accuracy: 0.3871 (38.71%)

# %% [markdown]
# # Understanding deep networks
#
# *   What is the use of activation functions in network? Why is it needed?
# *   We have used softmax activation function in the exercise. There are other activation functions available too. What is the difference between sigmoid activation and softmax activation?
# *   What is the difference between categorical crossentropy and binary crossentropy loss?

# %% [markdown]
# **Write the answers below :**
#
# 1 - **Use of activation functions:**
#
# Activation functions introduce **non-linearity** into the network. Without them, stacking multiple layers would collapse into a single linear transformation, making the network unable to learn complex patterns. Non-linear activations (ReLU, sigmoid, softmax) allow the model to approximate arbitrary functions and capture hierarchical features in the data.
#
# _
#
# 2 - **Key Differences between sigmoid and softmax:**
#
# | | Sigmoid | Softmax |
# |---|---|---|
# | **Output range** | Each neuron independently outputs a value in (0, 1) | All outputs sum to 1, forming a probability distribution |
# | **Use case** | Binary classification (single output) or multi-label problems | Multi-class classification (mutually exclusive classes) |
# | **Relationship** | Neurons are independent of each other | Each output depends on all others (normalized) |
#
# In short: sigmoid is used when classes are **not** mutually exclusive; softmax is used when exactly **one** class is correct.
#
# _
#
# 3 - **Key Differences between categorical crossentropy and binary crossentropy loss:**
#
# | | Categorical Crossentropy | Binary Crossentropy |
# |---|---|---|
# | **Target format** | One-hot encoded vector (multi-class, >2 classes) | Binary label 0 or 1 |
# | **Output activation** | Softmax (probabilities over C classes) | Sigmoid (single probability) |
# | **Use case** | Multi-class classification (mutually exclusive) | Binary or multi-label classification |
#
# Categorical crossentropy generalizes binary crossentropy to C classes. Use binary crossentropy when the output is a single probability; use categorical crossentropy when the output is a distribution over multiple classes.
#
# _

# %% [markdown]
# ## Reload Saved Models
#
# Use the cells below to reload any trained model without retraining.
# Make sure Drive is mounted and  is defined (run the setup cell at the top).

# %%
from tensorflow.keras.models import load_model

# Uncomment the model(s) you want to reload
# model1 = load_model(os.path.join(MODEL_DIR, 'model1.keras'))
# model2 = load_model(os.path.join(MODEL_DIR, 'model2.keras'))
# model3 = load_model(os.path.join(MODEL_DIR, 'model3.keras'))

# print('Model loaded successfully.')
# model1.summary()  # replace with model2 or model3 as needed
